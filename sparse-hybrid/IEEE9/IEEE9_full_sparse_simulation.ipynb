# %%
#sys path
from sys import path
from pathlib import Path

module_path = str(Path.cwd().parents[0])

if module_path not in path:
    path.append(module_path)
    
path.append(module_path + '\\functions')


# libraries
import pandas as pd
import numpy as np

import scipy.linalg
import matplotlib.pyplot as plt

from gp_regression import GPR
from gp_ccopf import GP_CCOPF
import save_outputs
import time

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

from sklearn.metrics import mean_squared_error

# %% [markdown]
# # DataSet

# %%
# Data Set

df = pd.read_csv('datasets\dataset_pandapower_AC.csv')
df.head()
# Out:
#    Unnamed: 0        Pg0         Pg1        Pg2     Load_P1     Load_P2  \
# 0           0  59.133076   91.046121  58.858774   77.773848   82.096546
# 1           1  66.599881  157.267682  92.238488  102.301461  104.046287
# 2           2  79.074452  134.389013  64.829596   95.968023  108.666208
# 3           3  49.510102  110.728146  72.459392   73.641679   89.800681
# 4           4  74.088754  104.415714  69.420999   86.981422   87.469644
#
#       Load_P3    Load_Q1    Load_Q2    Load_Q3      RS_P1      RS_P2  \
# 0  109.642025  25.924616  28.733791  43.856810  33.596406  29.744812
# 1  142.384024  34.100487  36.416200  56.953609  19.325453  17.635380
# 2  136.360049  31.989341  38.033173  54.544020  38.277040  28.240721
# 3  112.311358  24.547226  31.430238  44.924543  23.375186  22.872133
# 4  129.760427  28.993807  30.614375  51.904171  28.081316  31.604788
#
#        RS_Q1      RS_Q2         P0          P1         P2         P3  \
# 0  10.078922   9.914937 -58.856484  -91.046121 -58.858774 -33.596406
# 1   5.797636   5.878460 -68.289225 -157.267682 -92.238488 -19.325453
# 2  11.483112   9.413574 -79.420587 -134.389013 -64.829596 -38.277040
# 3   7.012556   7.624044 -49.481764 -110.728146 -72.459392 -23.375186
# 4   8.424395  10.534929 -74.322851 -104.415714 -69.420999 -28.081316
#
#            P4         P5          P6   P7          P8         Q0         Q1  \
# 0   77.773848 -29.744812   82.096546  0.0  109.642025   2.350474   6.317373
# 1  102.301461 -17.635380  104.046287  0.0  142.384024 -28.625599 -17.542616
# 2   95.968023 -28.240721  108.666208  0.0  136.360049 -14.588350 -10.672416
# 3   73.641679 -22.872133   89.800681  0.0  112.311358  -2.964563   1.712063
# 4   86.981422 -31.604788   87.469644  0.0  129.760427 -10.644654  -1.099562
#
#           Q2         Q3         Q4         Q5         Q6   Q7         Q8   U0  \
# 0  23.605955 -10.078922  25.924616  -9.914937  28.733791  0.0  43.856810  1.0
# 1   4.402647  -5.797636  34.100487  -5.878460  36.416200  0.0  56.953609  1.0
# 2  11.381477 -11.483112  31.989341  -9.413574  38.033173  0.0  54.544020  1.0
# 3  19.577410  -7.012556  24.547226  -7.624044  31.430238  0.0  44.924543  1.0
# 4  18.777980  -8.424395  28.993807 -10.534929  30.614375  0.0  51.904171  1.0
#
#     U1   U2        U3        U4        U5        U6        U7        U8  Ud0  \
# 0  1.0  1.0  1.001928  0.994936  1.014420  1.000038  1.005560  0.979805  0.0
# 1  1.0  1.0  0.984298  0.968655  1.004036  0.983771  0.993908  0.948376  0.0
\
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.526459    -2.313586    -0.266610    -5.591898    67.515772
# std       1.067584     1.105898     1.174581     0.806701    12.796164
# min      -2.779214    -5.626530    -3.790543    -8.550465    26.708616
# 25%      -0.247683    -3.081443    -1.105484    -6.085577    58.627945
# 50%       0.498588    -2.293111    -0.254460    -5.520943    66.731154
# 75%       1.283245    -1.519692     0.538861    -5.033661    76.259659
# max       3.696892     0.894783     3.663024    -3.309540   116.034781
#
#               P_34         P_45         P_25         P_56         P_67  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     40.641524   -49.880639    75.875898    50.807165   -49.786940
# std       7.712058     8.622159    14.004948     8.411371     9.769679
# min      21.184333   -76.866725    34.186272    30.474415   -91.002774
# 25%      35.312455   -55.406248    66.586935    44.813968   -56.242033
# 50%      40.271385   -49.640467    75.616361    50.104902   -49.228098
# 75%      45.513128   -44.419201    84.842674    56.414986   -42.935147
# max      67.463841   -19.899008   128.981432    83.980476   -23.804838
#
#               P_71         P_78         P_83
# count  1000.000000  1000.000000  1000.000000
# mean   -107.848401    57.833971   -69.003845
# std      18.946129    11.182085     9.852687
# min    -176.123871    22.051236  -102.581335
# 25%    -120.464337    50.402460   -74.917962
# 50%    -106.651498    57.655299   -68.282817
# 75%     -95.176695    65.154687   -62.201371
# max     -51.043491    94.942286   -43.300118

# %%
def _get_x(df):
    X = df[['Pg0', 'Pg1', 'Pg2', 'Load_P1', 'Load_P2', 'Load_P3', 'RS_P1', 'RS_P2']]
    return X 


def _get_y(df):
    y = df[['U3','U4', 'U5', 'U6', 'U7', 'U8', 
            'Q0', 'Q1', 'Q2', 
            'P_34', 'P_45', 'P_56', 'P_67', 'P_78' , 'P_83',
            ]]
    return y 


X = _get_x(df)
Y = _get_y(df)

Y[['U3','U4','U5', 'U6', 'U7', 'U8']] = Y[['U3','U4','U5', 'U6', 'U7', 'U8']]*345
# Out:
# C:\Users\milem\AppData\Local\Temp\ipykernel_13748\1031072827.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[['U3','U4','U5', 'U6', 'U7', 'U8']] = Y[['U3','U4','U5', 'U6', 'U7', 'U8']]*345

# %%
Nu = 3
Nd = 5

n_train = 75
n_test = n_train + 25

X_train = X.iloc[:n_train]  
Y_train = Y.iloc[:n_train]
X_train = X_train.to_numpy()
Y_train = Y_train.to_numpy()


X_test = X.iloc[n_train:n_test]
Y_test = Y.iloc[n_train:n_test]
X_test = X_test.to_numpy()
Y_test = Y_test.to_numpy()

# %% [markdown]
# # GP - Train and Save model

# %%
model = 0


print('*****************')
print('GP')
print('*****************')

M=10
Nc=1000

#Train
if model==0:
    gp = GPR(X_train, Y_train, M, Nc, normalize=True)
    gp.save_model('models/IEEE9')

#Load    
elif model==1:
    gp = GPR.load_model('models/IEEE9')


print('*****************')
print('Hyper_parameters')
print('*****************')
gp.print_hyper_parameters()
# Out:
# *****************
# GP
# *****************
#
# ________________________________________
# # Optimizing hyperparameters (N=75)
# ----------------------------------------
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: 36007904840.76576
#             Iterations: 2
#             Function evaluations: 31
#             Gradient evaluations: 2
# * Output 1:  0.031250 s
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: 436990955717.1034
#             Iterations: 1
#             Function evaluations: 11
#             Gradient evaluations: 1
# * Output 2:  0.015627 s
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: 437509682591.5544
#             Iterations: 1
#             Function evaluations: 11
#             Gradient evaluations: 1
# * Output 3:  0.024951 s
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: 427231678906.2959
#             Iterations: 1
#             Function evaluations: 11
#             Gradient evaluations: 1
# * Output 4:  0.024917 s
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: 424884838003.6112
#             Iterations: 1
#             Function evaluations: 11
#             Gradient evaluations: 1
# * Output 5:  0.018037 s
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: 441475246092.6696
#             Iterations: 1
#             Function evaluations: 11
#             Gradient evaluations: 1
# * Output 6:  0.017339 s
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: 431686948819.2869
#             Iterations: 1
#             Function evaluations: 11
#             Gradient evaluations: 1
# * Output 7:  0.015624 s
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: 423069702937.5002
#             Iterations: 1
#             Function evaluations: 11
#             Gradient evaluations: 1
# * Output 8:  0.022955 s
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: 438381805872.94727
#             Iterations: 1
#             Function evaluations: 11
#             Gradient evaluations: 1
# * Output 9:  0.016253 s
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: 467824329347.79236
#             Iterations: 1
#             Function evaluations: 11
#             Gradient evaluations: 1
# * Output 10:  0.016549 s
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: 79733440203.90665
#             Iterations: 2
#             Function evaluations: 32
#             Gradient evaluations: 2
# * Output 11:  0.043853 s
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: 443255757390.2429
#             Iterations: 1
#             Function evaluations: 11
#             Gradient evaluations: 1
# * Output 12:  0.015624 s
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: 449655063160.0408
#             Iterations: 1
#             Function evaluations: 11
#             Gradient evaluations: 1
# * Output 13:  0.002197 s
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: 408732139412.9497
#             Iterations: 1
#             Function evaluations: 11
#             Gradient evaluations: 1
# * Output 14:  0.022277 s
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: 422416240211.75745
#             Iterations: 1
#             Function evaluations: 11
#             Gradient evaluations: 1
# * Output 15:  0.018872 s
# ----------------------------------------
# *****************
# Hyper_parameters
# *****************
#
# ________________________________________
# # Hyper-parameters
# ----------------------------------------
# * Num samples: 75
# * Ny: 15
# * Nx: 8
# * Normalization: True
# ----------------------------------------
# * Lengthscale:  0
# -- l0: 0.9976676398972616
# -- l1: 0.9976676398972616
# -- l2: 0.9976676398972618
# -- l3: 1.4688279398434234
# -- l4: 1.4688279398434236
# -- l5: 0.9976676398972613
# -- l6: 0.997667639897261
# -- l7: 0.9976676398972613
# * Signal variance:  0
# -- sf2: 0.995293711811344
# * Noise variance:  0
# -- sn2: 1.1246387319530693e-09
# ----------------------------------------
# * Lengthscale:  1
# -- l0: 1.0000000000000002
# -- l1: 1.0000000000000002
# -- l2: 1.0000000000000004
# -- l3: 1.0
# -- l4: 1.0000000000000002
# -- l5: 0.9999999999999999
# -- l6: 0.9999999999999997
# -- l7: 0.9999999999999999
# * Signal variance:  1
# -- sf2: 1.0
# * Noise variance:  1
# -- sn2: 1.0000000000000002e-10
# ----------------------------------------
# * Lengthscale:  2
# -- l0: 1.0000000000000002
# -- l1: 1.0000000000000002
# -- l2: 1.0000000000000004
# -- l3: 1.0
# -- l4: 1.0000000000000002
# -- l5: 0.9999999999999999
# -- l6: 0.9999999999999997
# -- l7: 0.9999999999999999
# * Signal variance:  2
# -- sf2: 1.0000000000000004
# * Noise variance:  2
# -- sn2: 1.0000000000000002e-10
# ----------------------------------------
# * Lengthscale:  3
# -- l0: 1.0000000000000002
# -- l1: 1.0000000000000002
# -- l2: 1.0000000000000004
# -- l3: 1.0
# -- l4: 1.0000000000000002
# -- l5: 0.9999999999999999
# -- l6: 0.9999999999999997
# -- l7: 0.9999999999999999
# * Signal variance:  3
# -- sf2: 1.0
# * Noise variance:  3
# -- sn2: 1.0000000000000002e-10
# ----------------------------------------
# * Lengthscale:  4
# -- l0: 1.0000000000000002
# -- l1: 1.0000000000000002
# -- l2: 1.0000000000000004
# -- l3: 1.0
# -- l4: 1.0000000000000002
# -- l5: 0.9999999999999999
# -- l6: 0.9999999999999997
# -- l7: 0.9999999999999999
# * Signal variance:  4
# -- sf2: 0.9999999999999996
# * Noise variance:  4
# -- sn2: 1.0000000000000002e-10
# ----------------------------------------
# * Lengthscale:  5
# -- l0: 1.0000000000000002
# -- l1: 1.0000000000000002
# -- l2: 1.0000000000000004
# -- l3: 1.0
# -- l4: 1.0000000000000002
# -- l5: 0.9999999999999999
# -- l6: 0.9999999999999997
# -- l7: 0.9999999999999999
# * Signal variance:  5
# -- sf2: 1.0
# * Noise variance:  5
# -- sn2: 1.0000000000000002e-10
# ----------------------------------------
# * Lengthscale:  6
# -- l0: 1.0000000000000002
# -- l1: 1.0000000000000002
# -- l2: 1.0000000000000004
# -- l3: 1.0
# -- l4: 1.0000000000000002
# -- l5: 0.9999999999999999
# -- l6: 0.9999999999999997
# -- l7: 0.9999999999999999
# * Signal variance:  6
# -- sf2: 1.0
# * Noise variance:  6
# -- sn2: 1.0000000000000002e-10
# ----------------------------------------
# * Lengthscale:  7
# -- l0: 1.0000000000000002
# -- l1: 1.0000000000000002
# -- l2: 1.0000000000000004
# -- l3: 1.0
# -- l4: 1.0000000000000002
# -- l5: 0.9999999999999999
# -- l6: 0.9999999999999997
# -- l7: 0.9999999999999999
# * Signal variance:  7
# -- sf2: 0.9999999999999998
# * Noise variance:  7
# -- sn2: 1.0000000000000002e-10
# ----------------------------------------
# * Lengthscale:  8
# -- l0: 1.0000000000000002
# -- l1: 1.0000000000000002
# -- l2: 1.0000000000000004
# -- l3: 1.0
# -- l4: 1.0000000000000002
# -- l5: 0.9999999999999999
# -- l6: 0.9999999999999997
# -- l7: 0.9999999999999999
# * Signal variance:  8
# -- sf2: 0.9999999999999996
# * Noise variance:  8
# -- sn2: 1.0000000000000002e-10
# ----------------------------------------
# * Lengthscale:  9
# -- l0: 1.0000000000000002
# -- l1: 1.0000000000000002
# -- l2: 1.0000000000000004
# -- l3: 1.0
# -- l4: 1.0000000000000002
# -- l5: 0.9999999999999999
# -- l6: 0.9999999999999997
# -- l7: 0.9999999999999999
# * Signal variance:  9
# -- sf2: 1.0
# * Noise variance:  9
# -- sn2: 1.0000000000000002e-10
# ----------------------------------------
# * Lengthscale:  10
# -- l0: 1.2284701107657536
# -- l1: 1.2284701107657536
# -- l2: 1.2284701107657539
# -- l3: 1.2284701107657534
# -- l4: 1.2284701107657536
# -- l5: 1.2284701107657532
# -- l6: 1.228470110765753
# -- l7: 1.2284701107657532
# * Signal variance:  10
# -- sf2: 1.240240844923467
# * Noise variance:  10
# -- sn2: 4.6093638925675e-10
# ----------------------------------------
# * Lengthscale:  11
# -- l0: 1.0000000000000002
# -- l1: 1.0000000000000002
# -- l2: 1.0000000000000004
# -- l3: 1.0
# -- l4: 1.0000000000000002
# -- l5: 0.9999999999999999
# -- l6: 0.9999999999999997
# -- l7: 0.9999999999999999
# * Signal variance:  11
# -- sf2: 1.0
# * Noise variance:  11
# -- sn2: 1.0000000000000002e-10
# ----------------------------------------
# * Lengthscale:  12
# -- l0: 1.0000000000000002
# -- l1: 1.0000000000000002
# -- l2: 1.0000000000000004
# -- l3: 1.0
# -- l4: 1.0000000000000002
# -- l5: 0.9999999999999999
# -- l6: 0.9999999999999997
# -- l7: 0.9999999999999999
# * Signal variance:  12
# -- sf2: 1.0
# * Noise variance:  12
# -- sn2: 1.0000000000000002e-10
# ----------------------------------------
# * Lengthscale:  13
# -- l0: 1.0000000000000002
# -- l1: 1.0000000000000002
# -- l2: 1.0000000000000004
# -- l3: 1.0
# -- l4: 1.0000000000000002
# -- l5: 0.9999999999999999
# -- l6: 0.9999999999999997
# -- l7: 0.9999999999999999
# * Signal variance:  13
# -- sf2: 0.9999999999999998
# * Noise variance:  13
# -- sn2: 1.0000000000000002e-10
# ----------------------------------------
# * Lengthscale:  14
# -- l0: 1.0000000000000002
# -- l1: 1.0000000000000002
# -- l2: 1.0000000000000004
# -- l3: 1.0
# -- l4: 1.0000000000000002
# -- l5: 0.9999999999999999
# -- l6: 0.9999999999999997
# -- l7: 0.9999999999999999
# * Signal variance:  14
# -- sf2: 0.9999999999999998
# * Noise variance:  14
# -- sn2: 1.0000000000000002e-10
# ----------------------------------------

# %% [markdown]
# # GP - Validation

# %%
print('*****************')
print('Validation - Validation Data')
print('*****************')


RMSE = gp.validate(X_test, Y_test)
print('RMSE:', np.mean(RMSE))
# Out:
# *****************
# Validation - Validation Data
# *****************
#
# ________________________________________
# # Validation of GP model
# ----------------------------------------
# * Num training samples: 75
# * Num test samples: 25
# ----------------------------------------
# * Root Mean Squared Error:
# 	- State 1: 0.003921
# 	- State 2: 0.005187
# 	- State 3: 0.002232
# 	- State 4: 0.004404
# 	- State 5: 0.002791
# 	- State 6: 0.008009
# 	- State 7: 0.076681
# 	- State 8: 0.051926
# 	- State 9: 0.044927
# 	- State 10: 0.071285
# 	- State 11: 0.053617
# 	- State 12: 0.066551
# 	- State 13: 0.080097
# 	- State 14: 0.080909
# 	- State 15: 0.071736
# ----------------------------------------
# RMSE: 0.0416181722215753

# %% [markdown]
# # Input parameters

# %%
# Input mean
Xd = np.array([[ 90.,  100., 125., 50, 30]])

# Participation factors
alpha = np.array([[0.313, 0.405, 0.281]]).T

# Costs
R = np.eye(Nu) * [0.1100, 0.0850, 0.1225]
R2 = np.ones(Nu) * [5, 1.2, 1]

# Control boundaries
ulb = [ 10,  10,  10]
uub = [250, 300, 270]

# Output boundaries
xlb = [310.5, 310.5, 310.5, 310.5, 310.5, 310.5, -100, -100, -100, -200,  -200, -200, -200, -200, -200]
xub = [379.5, 379.5, 379.5, 379.5, 379.5, 379.5,  100,  100,  100,  200,   200,  200,  200,  200,  200]

# Percentages
per_load = 0.15 
per_rs   = 0.3 
n_load   = 3

# %% [markdown]
# ### TA1

# %%
gp_opf_TA1 = GP_CCOPF(gp=gp, gp_method='TA1', predefine_probability_y=0.975, predefine_probability_u=0.999,
                      R=R, R2=R2, ulb=ulb, uub=uub, xlb=xlb, xub=xub, solver_opts=None, normalize=True,
                      X=X_train, Y=Y_train, Xd=Xd, alpha=alpha, per_load=per_load, per_rs=per_rs, n_load=n_load)
# Out:
# ----------------------------------------
# # Time to build GP CCOPF solver: 0.035216 sec

# %%
u_TA1, alpha_TA1, x_TA1, s_TA1, trace_covar_TA1, Xd_std = gp_opf_TA1.solve()

# Save outputs
gp_save = 0

if gp_save == 0:
    IEEE_dict = save_outputs.to_dict(x_TA1, s_TA1, u_TA1, alpha_TA1, trace_covar_TA1)
    save_outputs.save_model(IEEE_dict, 'outputs\IEEE9_TA1')
# Out:
# Total number of variables............................:       36
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       32
# Total number of inequality constraints...............:       54
#         inequality constraints with only lower bounds:       36
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       18
#
#
# Number of Iterations....: 10
#
#                                    (scaled)                 (unscaled)
# Objective...............:  1.4162666898336813e+003   2.4772422260764397e+003
# Dual infeasibility......:  6.8787906179105166e-008   1.2031936290916728e-007
# Constraint violation....:  7.6738615462090820e-013   7.6738615462090820e-013
# Complementarity.........:  2.1557033561596740e-008   3.7706170872383977e-008
# Overall NLP error.......:  6.8787906179105166e-008   1.2031936290916728e-007
#
#
# Number of objective function evaluations             = 11
# Number of objective gradient evaluations             = 11
# Number of equality constraint evaluations            = 11
# Number of inequality constraint evaluations          = 11
# Number of equality constraint Jacobian evaluations   = 11
# Number of inequality constraint Jacobian evaluations = 11
# Number of Lagrangian Hessian evaluations             = 10
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.009
# Total CPU secs in NLP function evaluations           =      0.015
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)        0 (       0)        11
#        nlp_g  |        0 (       0)        0 (       0)        11
#     nlp_grad  |        0 (       0)        0 (       0)         1
#   nlp_grad_f  |        0 (       0)        0 (       0)        12
#   nlp_hess_l  |   9.00ms (900.00us)   9.97ms (996.80us)        10
#    nlp_jac_g  |   6.00ms (500.00us)   4.51ms (375.92us)        12
#        total  |  26.00ms ( 26.00ms)  25.46ms ( 25.46ms)         1
# Status: Solve_Succeeded
# Number of iteration: 10
# CPU time: 0.026
# Optimal control:
#  [[ 61.50244453]
#  [101.94433998]
#  [ 71.55321549]]
# Alpha:
#  [[0.31327567]
#  [0.40541557]
#  [0.28130876]]
# Output mean:
#  [[345.37407232]
#  [341.26745098]
#  [348.76707915]
#  [341.91757243]
#  [345.16341158]
#  [336.00270227]
#  [  0.68628769]
#  [ -2.55490836]
#  [ 18.7641172 ]
#  [ 42.15492127]
#  [-43.26106857]
#  [ 49.494348  ]
#  [-44.72588211]
#  [ 48.91610409]
#  [-72.60219219]]
# Output variance:
#  [[  5.07208772]
#  [ 15.48759374]
#  [  2.4694778 ]
#  [  4.96666585]
#  [  1.99507717]
#  [ 27.77335127]
#  [143.16989018]
#  [ 59.79736162]
#  [ 44.31788257]
#  [ 70.19698904]
#  [ 77.69343021]
#  [ 92.4720894 ]
#  [123.56384914]
#  [174.20531614]
#  [126.20212271]]

# %% [markdown]
# # Error metric

# %%
gp = GPR.load_model('models/IEEE9')


TA1_dict = save_outputs.load_model('outputs\IEEE9_TA1')
x_TA1 = np.array(TA1_dict['x'])
s_TA1 = np.array(TA1_dict['s'])
u_TA1 = np.array(TA1_dict['u'])
alpha_TA1 = np.array(TA1_dict['s'])
u_TA1 = np.array(TA1_dict['trace_covar'])

# %%
df_pf_ac_mean = pd.read_csv('datasets\dataset_tested_real_AC.csv')
df_pf_ac_mean[['U3','U4','U5', 'U6', 'U7', 'U8']] = df_pf_ac_mean[['U3','U4','U5', 'U6', 'U7', 'U8']]*345

def _get_outputs_ac(df_ac):
    V_ac = df_ac[['U3', 'U4', 'U5', 'U6', 'U7', 'U8', 'Q0', 'Q1', 'Q2', 'P_34', 'P_45', 'P_56', 'P_67', 'P_78', 'P_83']]
    return V_ac 

out_pf_ac_mean = _get_outputs_ac(df_pf_ac_mean)

out_pf_ac_mean = np.array(out_pf_ac_mean)
out_pf_ac_meanout_pf_ac_mean = out_pf_ac_mean[:9, :]
out_pf_ac_mean.shape
# Out:
# (1, 15)

# %%
out_pf_mean_pu = np.zeros((1,15))
x_TA1_pu = np.zeros((1,15))
x_EM_pu = np.zeros((1,15))

out_pf_mean_pu[:,:6] = out_pf_ac_mean[:,:6]/345
out_pf_mean_pu[:,6:] = out_pf_ac_mean[:,6:]/100

x_TA1_pu[:,:6] = x_TA1[:,:6]/345
x_TA1_pu[:,6:] = x_TA1[:,6:]/100


RMSE_average = mean_squared_error(out_pf_mean_pu.T, x_TA1_pu.T, multioutput='uniform_average', squared=False)
RMSE_row = mean_squared_error(out_pf_mean_pu, x_TA1_pu, multioutput='raw_values', squared=False)

print('RMSE_avrage:', RMSE_average)
print('')
print('RMSE_row:', RMSE_row)
# Out:
# RMSE_avrage: 0.024378595780648025
#
# RMSE_row: [0.00233309 0.00218584 0.00021289 0.00060605 0.00033521 0.00351028
#  0.04067476 0.0060072  0.01979058 0.00229548 0.04666213 0.0321171
#  0.02915071 0.05187826 0.00736422]
